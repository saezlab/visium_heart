# %%
suppressMessages(library(Seurat))
suppressMessages(library(SeuratData))
suppressMessages(library(SeuratDisk))
suppressMessages(library(dplyr))
# Out:
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”

# %%
obj <- readRDS("../visiumSpatial/from_rico/processed_visium/objects/AKK001_157785.rds")

# %%
obj
# Out:
# An object of class Seurat
# 30972 features across 3082 samples within 7 assays
# Active assay: SCT (15286 features, 3000 variable features)
#  6 other assays present: Spatial, dorothea, progeny, c2l, c2l_props, cell_states
#  2 dimensional reductions calculated: pca, umap

# %%
SpatialFeaturePlot(obj, 
                    features = "nCount_Spatial")
# Out:
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title

# %%
head(obj@images$slice1@coordinates)
# Out:
#                    tissue row col imagerow imagecol
# AAACAAGTATCTCCCA-1 1      50  102 5048     5649
# AAACAGAGCGACTCCT-1 1      14   94 2275     5285
# AAACATTTCCCGGATT-1 1      61   97 5897     5430
# AAACCGGGTAGGTACC-1 1      42   28 4442     2369
# AAACCGTTCGTCCAGG-1 1      52   42 5211     2992
# AAACCTAAGCAGCCGG-1 1      65   83 6207     4811
