# %%
suppressMessages(library(ArchR))
suppressMessages(library(Seurat))
suppressMessages(library(Signac))
suppressMessages(library(harmony))
suppressMessages(library(dplyr))
suppressMessages(library(cowplot))
suppressMessages(library(harmony))
suppressMessages(library(Nebulosa))
suppressMessages(library(ggpubr))
suppressMessages(library(Ipaper))
suppressMessages(library(phateR))
suppressMessages(library(parallel))
suppressMessages(library(ggrepel))

# %%
set.seed(42)
getwd()

addArchRThreads(threads = parallel::detectCores() - 2)
addArchRGenome("hg38")
# Out:
# [1] "/data/scATA/SingleCellOpenChromatin/local/VisiumHeartRevision/IntegrativeAnalysis/Cardiomyocyte/code"
# Setting default number of Parallel threads to 126.
#
# Setting default genome to Hg38.

# %%
## subset atac project
proj <- loadArchRProject("../data/snATAC_healthy_intermediate_damaged", showLogo = FALSE)
# Out:
# Successfully loaded ArchRProject!

# %%
p <- plotTrajectory(proj, trajectory = "healthy_intermediate_damaged", 
                    colorBy = "cellColData",
                    continuousSet = "blueYellow",
                    name = "healthy_intermediate_damaged",
                    embedding = "dm",
                    plotAs = "points",
                    rastr = FALSE,
                    addArrow = FALSE,
                    size = 1)

p1 <- p[[1]] + 
    theme_cowplot() +
    xlab("DC 1") + ylab("DC 2") +
    ggtitle("")


p2 <- plotEmbedding(proj, colorBy = "cellColData",
                   name = "annotation",
                    embedding = "dm",
                   plotAs = "points",
                   rastr = FALSE,
                   size = 1) + theme_cowplot() +
    xlab("DC 1") + ylab("DC 2") +
    ggtitle("")

options(repr.plot.width = 10, repr.plot.height = 5)

p1 + p2
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotTrajectory-3b51c82e680590-Date-2022-02-09_Time-14-39-13.log
# If there is an issue, please report to github with logFile!
#
# Plotting
#
# Plotting Trajectory
#
# ArchR logging successful to : ArchRLogs/ArchR-plotTrajectory-3b51c82e680590-Date-2022-02-09_Time-14-39-13.log
#
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-3b51c81adedb36-Date-2022-02-09_Time-14-39-15.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = cellColData
#
# Plotting Embedding
#
# 1
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-3b51c81adedb36-Date-2022-02-09_Time-14-39-15.log
# plot without title

# %%
trajMM  <- getTrajectory(ArchRProj = proj,
                         name = "healthy_intermediate_damaged",
                         useMatrix = "MotifMatrix",
                         log2Norm = FALSE,
                         scaleTo = NULL,
                        smoothWindow = 11)

trajMM <- trajMM[!grepl("deviations", rownames(trajMM)), ]

p1 <- plotTrajectoryHeatmap(trajMM, 
                            varCutOff = 0,
                            pal = paletteContinuous(set = "solarExtra"),
                            limits = c(-2, 2))

options(repr.plot.height = 8, repr.plot.width = 8)

p1
# Out:
# Creating Trajectory Group Matrix..
#
# Smoothing...
#
# ArchR logging to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c868119f49-Date-2022-02-09_Time-14-39-29.log
# If there is an issue, please report to github with logFile!
#
# useSeqnames is NULL or greater than 1 with a Sparse.Assays.Matrix trajectory input.
#
# 2022-02-09 14:39:29 :
#
# force=FALSE thus continuing with subsetting useSeqnames = z
#
# 2022-02-09 14:39:29 :
#
# Preparing Main Heatmap..
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# ArchR logging successful to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c868119f49-Date-2022-02-09_Time-14-39-29.log
# plot without title

# %%
trajGEX <- getTrajectory(ArchRProj = proj,
                         name = "healthy_intermediate_damaged",
                         useMatrix = "GeneExpressionMatrix",
                         log2Norm = TRUE,
                        smoothWindow = 11)

p2 <- plotTrajectoryHeatmap(trajGEX,
                        varCutOff = 0.5,
                        pal = paletteContinuous(set = "horizonExtra"),
                        limits = c(-2, 2))

p2
# Out:
# Creating Trajectory Group Matrix..
#
# Smoothing...
#
# ArchR logging to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c856a90aa1-Date-2022-02-09_Time-14-40-41.log
# If there is an issue, please report to github with logFile!
#
# Preparing Main Heatmap..
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# ArchR logging successful to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c856a90aa1-Date-2022-02-09_Time-14-40-41.log
# plot without title

# %%
options(repr.plot.height = 6, repr.plot.width = 12)

correlation_analysis <- function(trajMM, trajGEX, varCutOff1 = 0, varCutOff2 = 0,
                                 cor_threshold = 0.1){
    
    corMM_GEX <- correlateTrajectories(trajMM, trajGEX,
                                   varCutOff1 = varCutOff1,
                                   varCutOff2 = varCutOff2,
                                   corCutOff = 0)

    df <- as.data.frame(corMM_GEX[[1]])
    df <- df[!grepl("-AS", df$name2), ]
    df <- df[df$Correlation > cor_threshold, ]

    ## plot correlation
    p <- ggplot(data = df, aes(x = reorder(matchname1, -Correlation), y = Correlation)) +
        geom_point() +
        geom_text_repel(aes(label = matchname1)) +
        xlab("") + ggtitle(glue::glue("Number of TFs: {nrow(df)}")) +
        theme_cowplot() +
        theme(axis.ticks.x = element_blank(),
             axis.text.x = element_blank())
    
    print(p)

    df <- df[!duplicated(df$matchname1), ]
    
    trajMM2 <- trajMM[df$name1, ]
    trajGEX2 <- trajGEX[df$name2, ]

    trajCombined <- trajMM2

    assay(trajCombined, withDimnames=FALSE) <- t(apply(assay(trajGEX2), 1, scale)) + 
        t(apply(assay(trajMM2), 1, scale))

    combinedMat <- plotTrajectoryHeatmap(trajCombined,
                                         returnMat = TRUE,
                                         varCutOff = 0)

    rowOrder <- match(rownames(combinedMat), rownames(trajMM2))

    saveRDS(trajMM2, "../data/snATAC_healthy_intermediate_damaged/trajMM2.rds")
    saveRDS(trajGEX2, "../data/snATAC_healthy_intermediate_damaged/trajGEX2.rds")
    saveRDS(rowOrder, "../data/snATAC_healthy_intermediate_damaged/rowOrder.rds")
    
    ht1 <- plotTrajectoryHeatmap(trajMM2,
                                 pal = paletteContinuous(set = "solarExtra"),
                                 varCutOff = 0,
                                 rowOrder = rowOrder,
                                 limits = c(-2, 2),
                                 labelRows = TRUE,
                                labelTop = 100)

    ht2 <- plotTrajectoryHeatmap(trajGEX2,
                                 pal = paletteContinuous(set = "horizonExtra"),
                                 varCutOff = 0,
                                 rowOrder = rowOrder,
                                 limits = c(-2, 2),
                                 labelRows = TRUE,
                                labelTop = 100)


    options(repr.plot.height = 8, repr.plot.width = 10)

    draw(ht1 + ht2)
    
    return(df)

}

# %%
df1 <- correlation_analysis(trajMM, trajGEX, cor_threshold = 0.1, varCutOff1 = 0, varCutOff2 = 0.5)
write.csv(df1, "../data/snATAC_healthy_intermediate_damaged/sel_tf_by_expression.csv")
# Out:
# ArchR logging to : ArchRLogs/ArchR-correlateTrajectories-3b51c862042794-Date-2022-02-09_Time-14-40-57.log
# If there is an issue, please report to github with logFile!
#
# Found 124 Correlated Pairings!
#
# 2022-02-09 14:41:00 :
#
# Warning message:
# “ggrepel: 40 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# ArchR logging to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c858a3b81-Date-2022-02-09_Time-14-41-01.log
# If there is an issue, please report to github with logFile!
#
# useSeqnames is NULL or greater than 1 with a Sparse.Assays.Matrix trajectory input.
#
# 2022-02-09 14:41:01 :
#
# force=FALSE thus continuing with subsetting useSeqnames = z
#
# 2022-02-09 14:41:01 :
#
# Preparing Main Heatmap..
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# ArchR logging successful to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c858a3b81-Date-2022-02-09_Time-14-41-01.log
#
# ArchR logging to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c86caae746-Date-2022-02-09_Time-14-41-01.log
# If there is an issue, please report to github with logFile!
#
# useSeqnames is NULL or greater than 1 with a Sparse.Assays.Matrix trajectory input.
#
# 2022-02-09 14:41:01 :
#
# force=FALSE thus continuing with subsetting useSeqnames = z
#
# 2022-02-09 14:41:01 :
#
# Preparing Main Heatmap..
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# ArchR logging successful to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c86caae746-Date-2022-02-09_Time-14-41-01.log
#
# ArchR logging to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c85b219677-Date-2022-02-09_Time-14-41-01.log
# If there is an issue, please report to github with logFile!
#
# Preparing Main Heatmap..
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# ArchR logging successful to : ArchRLogs/ArchR-plotTrajectoryHeatmap-3b51c85b219677-Date-2022-02-09_Time-14-41-01.log
# plot without title
# plot without title

# %%
# df1 <- correlation_analysis(trajMM, trajGSM, cor_threshold = 0.1, varCutOff1 = 0, varCutOff2 = 0.5)
# df2 <- correlation_analysis(trajMM, trajGSM, cor_threshold = 0.2, varCutOff1 = 0, varCutOff2 = 0.5)

# write.csv(df1, "../data/snATAC_SCARA5_Myofib/sel_tf_by_accessibility.csv")

# %%
# proj <- addImputeWeights(proj, reducedDims = "Harmony")

# %%
# if(!dir.exists("../data/snATAC_healthy_intermediate_damaged/SelectedTFByExpression"))
# {
#     dir.create("../data/snATAC_healthy_intermediate_damaged/SelectedTFByExpression")

# }

# df <- read.csv("../data/snATAC_healthy_intermediate_damaged/sel_tf_by_expression.csv", row.names = 1)

# for(i in 1:nrow(df)){
#     tf_name = df$name1[[i]]
#     gene_name = df$matchname1[[i]]
    
    
#     p1 <- plotEmbedding(
#     ArchRProj = proj, 
#     colorBy = "MotifMatrix", 
#     log2Norm = TRUE,
#     name = tf_name, 
#     embedding = "dm",
#     quantCut = c(0.1, 0.95),
#     imputeWeights = getImputeWeights(proj),
#      plotAs = "points",
#     rastr = FALSE,
#     size = 1.5,
#     pal = paletteContinuous(set = "solarExtra")
# ) + theme_cowplot() + theme(legend.title = element_blank()) + 
#     ggtitle(glue::glue("TF activity: {gene_name}"))

# p2 <- plotEmbedding(
#     ArchRProj = proj, 
#     colorBy = "GeneExpressionMatrix", 
#     log2Norm = FALSE,
#     name = gene_name, 
#     embedding = "dm",
#     quantCut = c(0.05, 0.95),
#     imputeWeights = getImputeWeights(proj),
#      plotAs = "points",
#     rastr = FALSE,
#     size = 1.5,
#     pal = paletteContinuous(set = "horizonExtra")
# )+ theme_cowplot()+ theme(legend.title = element_blank())+ 
#     ggtitle(glue::glue("TF expression: {gene_name}"))
    
#     p3 <- plotTrajectory(proj, 
#                          trajectory = "healthy_intermediate_damaged", 
#                          colorBy = "MotifMatrix", 
#                          name = tf_name, 
#                          continuousSet = "solarExtra",
#                         plotAs = "points",
#     rastr = FALSE,
#     size = 1.5)
    
#     p3 <- p3[[2]] + theme_cowplot()
    
#     p4 <- plotTrajectory(proj, 
#                          trajectory = "healthy_intermediate_damaged", 
#                          colorBy = "GeneExpressionMatrix", 
#                          name = gene_name, 
#                          continuousSet = "horizonExtra",
#                         plotAs = "points",
#     rastr = FALSE,
#     size = 1.5)
    
#     p4 <- p4[[2]] + theme_cowplot()
    
#     options(repr.plot.height = 10, repr.plot.width = 10)
    
#     p <- patchwork::wrap_plots(list(p1, p2, p3, p4), nrow = 2)
# #    print(p)
    
#     pdf(glue::glue("../data/snATAC_healthy_intermediate_damaged/SelectedTFByExpression/{gene_name}.pdf"), 
#         height = 10, width = 10)
#     print(p)
#     dev.off()
# }

# %%
# if(!dir.exists("../data/snATAC_SCARA5_Myofib/SelectedTFByAccessibility"))
# {
#     dir.create("../data/snATAC_SCARA5_Myofib/SelectedTFByAccessibility")

# }

# df <- read.csv("../data/snATAC_SCARA5_Myofib/sel_tf_by_accessibility.csv", row.names = 1)

# for(i in 1:nrow(df)){
#     tf_name = df$name1[[i]]
#     gene_name = df$matchname1[[i]]
    
    
#     p1 <- plotEmbedding(
#     ArchRProj = proj, 
#     colorBy = "MotifMatrix", 
#     log2Norm = TRUE,
#     name = tf_name, 
#     embedding = "dm",
#     quantCut = c(0.1, 0.95),
#     imputeWeights = getImputeWeights(proj),
#      plotAs = "points",
#     rastr = FALSE,
#     size = 1.5,
#     pal = paletteContinuous(set = "solarExtra")
# ) + theme_cowplot() + theme(legend.title = element_blank()) + 
#     ggtitle(glue::glue("TF activity: {gene_name}"))

# p2 <- plotEmbedding(
#     ArchRProj = proj, 
#     colorBy = "GeneScoreMatrix", 
#     log2Norm = FALSE,
#     name = gene_name, 
#     embedding = "dm",
#     quantCut = c(0.05, 0.95),
#     imputeWeights = getImputeWeights(proj),
#      plotAs = "points",
#     rastr = FALSE,
#     size = 1.5,
#     pal = paletteContinuous(set = "horizonExtra")
# )+ theme_cowplot()+ theme(legend.title = element_blank())+ 
#     ggtitle(glue::glue("TF accessibility: {gene_name}"))
    
#     p3 <- plotTrajectory(proj, 
#                          trajectory = "SCARA5_Myofib_dm", 
#                          colorBy = "MotifMatrix", 
#                          name = tf_name, 
#                          continuousSet = "solarExtra",
#                         plotAs = "points",
#     rastr = FALSE,
#     size = 1.5)
    
#     p3 <- p3[[2]] + theme_cowplot()
    
#     p4 <- plotTrajectory(proj, 
#                          trajectory = "SCARA5_Myofib_dm", 
#                          colorBy = "GeneScoreMatrix", 
#                          name = gene_name, 
#                          continuousSet = "horizonExtra",
#                         plotAs = "points",
#     rastr = FALSE,
#     size = 1.5)
    
#     p4 <- p4[[2]] + theme_cowplot()
    
#     options(repr.plot.height = 10, repr.plot.width = 10)
    
#     p <- patchwork::wrap_plots(list(p1, p2, p3, p4), nrow = 2)
#     #print(p)
    
#     pdf(glue::glue("../data/snATAC_SCARA5_Myofib/SelectedTFByAccessibility/{gene_name}.pdf"), 
#         height = 10, width = 10)
#     print(p)
#     dev.off()
# }

# %%
saveArchRProject(ArchRProj = proj, load = FALSE)
# Out:
# Saving ArchRProject...

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: CentOS Linux 8
#
# Matrix products: default
# BLAS/LAPACK: /home/rs619065/miniconda3/envs/r-4.1/lib/libopenblasp-r0.3.18.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
#  [1] grid      parallel  stats4    stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] circlize_0.4.13             ComplexHeatmap_2.10.0
#  [3] ggrepel_0.9.1               phateR_1.0.7
#  [5] Ipaper_0.1.8                ggpubr_0.4.0
#  [7] Nebulosa_1.4.0              patchwork_1.1.1
#  [9] cowplot_1.1.1               dplyr_1.0.7
# [11] harmony_0.1.0               Rcpp_1.0.7
# [13] Signac_1.5.0                SeuratObject_4.0.4
# [15] Seurat_4.0.5                ArchR_1.0.1
# [17] magrittr_2.0.1              rhdf5_2.38.0
# [19] Matrix_1.4-0                data.table_1.14.2
# [21] SummarizedExperiment_1.24.0 Biobase_2.54.0
# [23] GenomicRanges_1.46.1        GenomeInfoDb_1.30.0
# [25] IRanges_2.28.0              S4Vectors_0.32.3
# [27] BiocGenerics_0.40.0         MatrixGenerics_1.6.0
# [29] matrixStats_0.61.0          ggplot2_3.3.5
#
# loaded via a namespace (and not attached):
#   [1] utf8_1.2.2                        clipr_0.7.1
#   [3] reticulate_1.22                   ks_1.13.2
#   [5] tidyselect_1.1.1                  htmlwidgets_1.5.4
#   [7] docopt_0.7.1                      BiocParallel_1.28.2
#   [9] Rtsne_0.15                        munsell_0.5.0
#  [11] codetools_0.2-18                  ica_1.0-2
#  [13] pbdZMQ_0.3-6                      future_1.23.0
#  [15] miniUI_0.1.1.1                    withr_2.4.3
#  [17] colorspace_2.0-2                  uuid_1.0-3
#  [19] rstudioapi_0.13                   SingleCellExperiment_1.16.0
#  [21] ROCR_1.0-11                       ggsignif_0.6.3
#  [23] tensor_1.5                        listenv_0.8.0
#  [25] labeling_0.4.2                    slam_0.1-49
#  [27] repr_1.1.3                        GenomeInfoDbData_1.2.7
#  [29] polyclip_1.10-0                   farver_2.1.0
#  [31] parallelly_1.29.0                 vctrs_0.3.8
#  [33] generics_0.1.1                    lsa_0.73.2
#  [35] ggseqlogo_0.1                     R6_2.5.1
#  [37] doParallel_1.0.16                 clue_0.3-60
#  [39] cachem_1.0.6                      bitops_1.0-7
#  [41] rhdf5filters_1.6.0                spatstat.utils_2.2-0
#  [43] DelayedArray_0.20.0               assertthat_0.2.1
#  [45] BiocIO_1.4.0                      promises_1.2.0.1
#  [47] scales_1.1.1                      gtable_0.3.0
#  [49] Cairo_1.5-12.2                    globals_0.14.0
#  [51] goftest_1.2-3                     rlang_0.4.12
#  [53] RcppRoll_0.3.0                    GlobalOptions_0.1.2
#  [55] splines_4.1.1                     rtracklayer_1.54.0
#  [57] rstatix_0.7.0                     lazyeval_0.2.2
#  [59] spatstat.geom_2.3-0               broom_0.7.10
#  [61] yaml_2.2.1                        reshape2_1.4.4
#  [63] abind_1.4-5                       backports_1.4.0
#  [65] httpuv_1.6.3                      tools_4.1.1
#  [67] ellipsis_0.3.2                    spatstat.core_2.3-2
#  [69] RColorBrewer_1.1-2                ggridges_0.5.3
#  [71] plyr_1.8.6                        base64enc_0.1-3
#  [73] zlibbioc_1.40.0                   purrr_0.3.4
#  [75] RCurl_1.98-1.5                    rpart_4.1-15
#  [77] deldir_1.0-6                      GetoptLong_1.0.5
#  [79] pbapply_1.5-0                     zoo_1.8-9
#  [81] cluster_2.1.2                     scattermore_0.7
#  [83] openxlsx_4.2.4                    lmtest_0.9-39
#  [85] RANN_2.6.1                        mvtnorm_1.1-3
#  [87] SnowballC_0.7.0                   fitdistrplus_1.1-6
#  [89] mime_0.12                         evaluate_0.14
#  [91] xtable_1.8-4                      XML_3.99-0.8
#  [93] mclust_5.4.8                      sparsesvd_0.2
#  [95] readxl_1.3.1                      shape_1.4.6
#  [97] gridExtra_2.3                     compiler_4.1.1
#  [99] tibble_3.1.6                      KernSmooth_2.23-20
# [101] crayon_1.4.2                      htmltools_0.5.2
# [103] mgcv_1.8-38                       later_1.3.0
# [105] tidyr_1.1.4                       lubridate_1.8.0
# [107] DBI_1.1.1                         tweenr_1.0.2
# [109] MASS_7.3-54                       car_3.0-12
# [111] igraph_1.2.9                      pkgconfig_2.0.3
# [113] GenomicAlignments_1.30.0          IRdisplay_1.0
# [115] plotly_4.10.0                     spatstat.sparse_2.0-0
# [117] foreach_1.5.1                     XVector_0.34.0
# [119] BSgenome.Hsapiens.UCSC.hg38_1.4.4 stringr_1.4.0
# [121] digest_0.6.29                     sctransform_0.3.2
# [123] RcppAnnoy_0.0.19                  pracma_2.3.6
# [125] spatstat.data_2.1-0               Biostrings_2.62.0
# [127] cellranger_1.1.0                  leiden_0.3.9
# [129] fastmatch_1.1-3                   uwot_0.1.11
# [131] restfulr_0.0.13                   gtools_3.9.2
# [133] shiny_1.7.1                       Rsamtools_2.10.0
# [135] rjson_0.2.20                      lifecycle_1.0.1
# [137] nlme_3.1-153                      jsonlite_1.7.2
# [139] Rhdf5lib_1.16.0                   carData_3.0-4
# [141] BSgenome_1.62.0                   viridisLite_0.4.0
# [143] fansi_0.5.0                       pillar_1.6.4
# [145] lattice_0.20-45                   fastmap_1.1.0
# [147] httr_1.4.2                        survival_3.2-13
# [149] glue_1.5.1                        remotes_2.4.2
# [151] qlcMatrix_0.9.7                   zip_2.2.0
# [153] png_0.1-7                         iterators_1.0.13
# [155] ggforce_0.3.3                     stringi_1.7.6
# [157] memoise_2.0.1                     IRkernel_1.3.0.9000
# [159] irlba_2.3.5                       future.apply_1.8.1
