# %%
suppressMessages(library(ArchR))
suppressMessages(library(Seurat))
suppressMessages(library(Signac))
suppressMessages(library(harmony))
suppressMessages(library(dplyr))
suppressMessages(library(cowplot))
suppressMessages(library(harmony))
suppressMessages(library(Nebulosa))
suppressMessages(library(ggpubr))
suppressMessages(library(Ipaper))
suppressMessages(library(phateR))
suppressMessages(library(ComplexHeatmap))

# %%
proj <- loadArchRProject("../data/snATAC_subset", showLogo = FALSE)
# Out:
# Successfully loaded ArchRProject!

# %%
p <- plotBrowserTrack(
    ArchRProj = proj, 
    groupBy = "annotation", 
    geneSymbol = c("FLT4"), 
    plotSummary = c("bulkTrack", "geneTrack"),
    upstream = 50000,
    downstream = 50000,
    verbose = FALSE
)
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotBrowserTrack-1abd3b3bcd22aa-Date-2022-02-28_Time-11-54-02.log
# If there is an issue, please report to github with logFile!
# GRanges object with 1 range and 2 metadata columns:
#       seqnames              ranges strand |     gene_id      symbol
#          <Rle>           <IRanges>  <Rle> | <character> <character>
#   [1]     chr5 180601506-180649624      - |        2324        FLT4
#   -------
#   seqinfo: 24 sequences from hg38 genome
# Getting Region From Arrow Files 1 of 25
#
# Getting Region From Arrow Files 2 of 25
#
# Getting Region From Arrow Files 3 of 25
#
# Getting Region From Arrow Files 4 of 25
#
# Getting Region From Arrow Files 5 of 25
#
# Getting Region From Arrow Files 6 of 25
#
# Getting Region From Arrow Files 7 of 25
#
# Getting Region From Arrow Files 8 of 25
#
# Getting Region From Arrow Files 9 of 25
#
# Getting Region From Arrow Files 10 of 25
#
# Getting Region From Arrow Files 11 of 25
#
# Getting Region From Arrow Files 12 of 25
#
# Getting Region From Arrow Files 13 of 25
#
# Getting Region From Arrow Files 14 of 25
#
# Getting Region From Arrow Files 15 of 25
#
# Getting Region From Arrow Files 16 of 25
#
# Getting Region From Arrow Files 17 of 25
#
# Getting Region From Arrow Files 18 of 25
#
# Getting Region From Arrow Files 19 of 25
#
# Getting Region From Arrow Files 20 of 25
#
# Getting Region From Arrow Files 21 of 25
#
# Getting Region From Arrow Files 22 of 25
#
# Getting Region From Arrow Files 23 of 25
#
# Getting Region From Arrow Files 24 of 25
#
# Getting Region From Arrow Files 25 of 25
#
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# ArchR logging successful to : ArchRLogs/ArchR-plotBrowserTrack-1abd3b3bcd22aa-Date-2022-02-28_Time-11-54-02.log

# %%
options(repr.plot.height = 6, repr.plot.width = 4)

grid::grid.draw(p$FLT4)
# Out:
# plot without title
