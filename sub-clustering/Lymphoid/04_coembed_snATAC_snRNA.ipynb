# %%
suppressMessages(library(ArchR))
suppressMessages(library(Seurat))
suppressMessages(library(Signac))
suppressMessages(library(harmony))
suppressMessages(library(dplyr))
suppressMessages(library(cowplot))

# %%
set.seed(42)

# %%
proj <- loadArchRProject("../data/snATAC", showLogo = FALSE)
# Out:
# Successfully loaded ArchRProject!

# %%
p1 <- plotEmbedding(ArchRProj = proj, 
              colorBy = "cellColData", 
              name = "Clusters", embedding = "UMAP_Harmony",plotAs = "points",
                   size = 0.5, labelAsFactors = FALSE, rastr = FALSE) +
    theme_cowplot()

options(repr.plot.height = 6, repr.plot.width = 6)

p1
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-35cffc12018e60-Date-2021-11-17_Time-11-07-57.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = cellColData
#
# Plotting Embedding
#
# 1
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-35cffc12018e60-Date-2021-11-17_Time-11-07-57.log
# plot without title

# %%
table(proj@cellColData$Clusters)
# Out:
#  C1  C2  C3  C4
#  79 271 370 450

# %%
peak_counts <- readRDS("../data/snATAC/PeakMatrix.Rds")
dim(peak_counts)
# Out:
# [1] 521947   1170

# %%
## cluster 1-3 seems to be outlier, we here removed it from downstream analysis
metadata <- as.data.frame(proj@cellColData) %>%
    subset(., select = c("Sample", "Clusters", "region", "patient", "patient_region_id", "patient_group")) #%>%
    #subset(., Clusters %in% c("C4", "C5", "C6", "C7", "C8") )


head(metadata)

peak_counts_sub <- peak_counts[, rownames(metadata)]

dim(peak_counts_sub)
# Out:
#                          Sample Clusters region patient patient_region_id
# CK171#AAATGCCTCGATGTGT-1 CK171  C3       RZ/BZ  P2      RZ/BZ_P2
# CK171#TTCATCAAGAAATACC-1 CK171  C4       RZ/BZ  P2      RZ/BZ_P2
# CK171#CCCTGATTCCGTGCAG-1 CK171  C4       RZ/BZ  P2      RZ/BZ_P2
# CK171#TGGTCAAAGTATAGTG-1 CK171  C4       RZ/BZ  P2      RZ/BZ_P2
# CK171#TCACCACAGCCATCAT-1 CK171  C4       RZ/BZ  P2      RZ/BZ_P2
# CK171#GAGCGCTCAATGGTCT-1 CK171  C4       RZ/BZ  P2      RZ/BZ_P2
#                          patient_group
# CK171#AAATGCCTCGATGTGT-1 group_1
# CK171#TTCATCAAGAAATACC-1 group_1
# CK171#CCCTGATTCCGTGCAG-1 group_1
# CK171#TGGTCAAAGTATAGTG-1 group_1
# CK171#TCACCACAGCCATCAT-1 group_1
# CK171#GAGCGCTCAATGGTCT-1 group_1
# [1] 521947   1170

# %%
table(metadata$Clusters)
# Out:
#  C1  C2  C3  C4
#  79 271 370 450

# %%
chrom_assay <- CreateChromatinAssay(
  counts = peak_counts_sub,
  sep = c("_", "_"),
  min.cells = 10
)

obj.atac <- CreateSeuratObject(
  counts = chrom_assay,
  assay = "peaks",
  meta.data = metadata,
  names.field = 1, 
  names.delim = "#")

obj.atac
# Out:
# An object of class Seurat
# 111685 features across 1170 samples within 1 assay
# Active assay: peaks (111685 features, 0 variable features)

# %%
## add dimension reduced matrix
harmony_matDR <- proj@reducedDims$Harmony$matDR
colnames(harmony_matDR) <- paste0("Harmony_", 1:ncol(harmony_matDR))
harmony_matDR <- harmony_matDR[colnames(obj.atac), ]

obj.atac[["harmony"]] <- CreateDimReducObject(embeddings = harmony_matDR,
                                             assay = DefaultAssay(obj.atac),
                                             key = "Harmony_")

embedding <- proj@embeddings$UMAP_Harmony$df
colnames(embedding) <- paste0("UMAP_", 1:ncol(embedding))
embedding <- embedding[colnames(obj.atac), ]

#head(embedding)
obj.atac[["umap"]] <- CreateDimReducObject(embeddings = as.matrix(embedding),
                                             assay = "peaks",
                                             key = "UMAP_")

# %%
obj.atac <- RunUMAP(obj.atac, 
               dims = 1:30, 
               reduction = 'harmony',
               reduction.name = "umap_harmony",
               reduction.ke = 'umapharmony_',
              verbose = FALSE,
                   min.dist = 0.4)
# Out:
# Warning message:
# “The default method for RunUMAP has changed from calling Python UMAP via reticulate to the R-native UWOT using the cosine metric
# To use Python UMAP via reticulate, set umap.method to 'umap-learn' and metric to 'correlation'
# This message will be shown once per session”

# %%
cols.clusters <- ArchR::paletteDiscrete(metadata$Clusters)

# %%
options(repr.plot.height = 8, repr.plot.width = 10)
p1 <- DimPlot(obj.atac, group.by = "Clusters", pt.size = 1, cols = cols.clusters)

p1
# Out:
# plot without title

# %%
## load snRNA-seq data
obj.rna <- readRDS("../data/snRNA/snRNA.rds")
obj.rna
# Out:
# An object of class Seurat
# 28933 features across 4962 samples within 1 assay
# Active assay: RNA (28933 features, 2000 variable features)
#  4 dimensional reductions calculated: pca, harmony, umap, umap_harmony

# %%
DimPlot(obj.rna, pt.size = 1, reduction = "umap_harmony")
# Out:
# plot without title

# %%
# obj.rna <- subset(obj.rna, orig.ident %in% df_cell_count$orig.ident)
# obj.rna

# %%
## add gene activity score
gene.activities <- readRDS("../data/snATAC/GeneScoreMatrix.Rds")

dim(gene.activities)

gene.use <- intersect(rownames(gene.activities),
                     rownames(obj.rna))

length(gene.use)

obj.atac[['GeneActivity']] <- CreateAssayObject(counts = gene.activities[gene.use, colnames(obj.atac)])

DefaultAssay(obj.atac) <- "GeneActivity"

obj.atac <- obj.atac %>% 
        NormalizeData() %>%
        FindVariableFeatures() %>%
        ScaleData()
# Out:
# [1] 24919  1170
# [1] 19026
# Centering and scaling data matrix

# %%
transfer.anchors <- FindTransferAnchors(reference = obj.rna,
                                        query = obj.atac,
                                        features = gene.use,
                                        reference.assay = "RNA",
                                        query.assay = "GeneActivity",
                                        reduction = "cca")
# Out:
# Warning message in RunCCA.Seurat(object1 = reference, object2 = query, features = features, :
# “Running CCA on different assays”
# Running CCA
#
# Merging objects
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 5412 anchors
#
# Filtering anchors
#
# 	Retained 1651 anchors

# %%
# note that we restrict the imputation to variable genes from scRNA-seq, but could impute the
# full transcriptome if we wanted to
refdata <- GetAssayData(obj.rna, assay = "RNA", slot = "data")[gene.use, ]

# refdata (input) contains a scRNA-seq expression matrix for the scRNA-seq cells. imputation
# (output) will contain an imputed scRNA-seq matrix for each of the ATAC cells
imputation <- TransferData(anchorset = transfer.anchors, 
                           refdata = refdata, 
                           weight.reduction = obj.atac[["harmony"]],
                           dims = 1:30)
obj.atac[["RNA"]] <- imputation
# Out:
# Finding integration vectors
#
# Finding integration vector weights
#
# Transfering 19026 features onto reference data

# %%
DefaultAssay(obj.atac) <- "RNA"
obj.rna$tech <- "RNA"
obj.atac$tech <- "ATAC"
coembed <- merge(x = obj.atac, y = obj.rna)

# %%
#Finally, we run PCA and UMAP on this combined object, to visualize the co-embedding of both datasets
coembed <- coembed %>%
    ScaleData(features = gene.use, do.scale = FALSE) %>%
    FindVariableFeatures() %>%
    RunPCA() %>%
    RunUMAP(dims = 1:30, verbose = FALSE)
# Out:
# Centering data matrix
#
# Warning message in PrepDR(object = object, features = features, verbose = verbose):
# “The following 566 features requested have not been scaled (running reduction without them): AL136456.1, LINC02694, AC243829.2, AL590807.1, AL162493.1, CCL4, AC011246.1, AC093865.1, AP001636.3, AC064834.1, AP002989.1, AC139720.1, AC012409.2, Z93403.1, LINC02341, AL109930.1, AC007611.1, AC005165.1, AP001783.1, SLC5A4-AS1, AC114971.1, AL031599.1, AL035446.2, AC246817.1, TAFA1, LINC00355, AL138828.1, AC005833.2, AL589693.1, IGKC, AC104035.1, AP002518.2, MIR4422HG, AP003066.1, IGHM, AC010343.3, LINC01982, AP002852.1, IGHGP, AC007319.1, AC010327.4, LINC02725, AC009570.2, IGHG3, ERVMER61-1, AL392086.3, AC010967.1, AL359704.3, AC136424.2, AL136962.1, AL499616.1, LINC01807, AC073332.1, IQCM, AC012494.1, IGLC2, AL034397.2, LINC01362, AL392023.2, AC104041.1, AC006378.1, AL163932.1, AC119868.2, AL353653.1, AL357873.1, SMIM41, AC013652.1, LINC02055, AC023424.3, AC106798.1, LINC02759, AC110491.2, AL138689.2, AC027237.3, AC104078.1, AC103843.1, AL078459.1, AC002072.1, AC073957.1, AC005842.1, IGLC1, BX322234.1, AC012636.1, LINC02233, GP1BB, AC137810.1, AC068051.1, IGHA1, AC025887.2, AL513166.1, AC016597.1, LINC02840, AC005580.1, AC117383.1, AC068234.2, AC013565.1, AP002892.1, AL445250.1, AP003472.2, AC079793.1, AC026341.1, AC132153.1, LINC02296, AL137024.1, AC090125.1, IGLC3, AC068633.1, AC020916.1, AL050309.1, CCN3, AL603840.1, AC095033.1, AL359258.2, AL357793.2, AC008170.1, AC016727.3, TBC1D8-AS1, AC079790.1, LINC02832, AC097713.1, MME-AS1, AC016687.2, AL035693.1, AP006248.4, AP005357.1, LINC02753, LINC02406, LINC02397, AC089999.2, AC109597.2, AP001496.1, LINC01905, AC091691.2, BX640514.1, AC009803.1, CR392039.4, AC026495.1, AC005162.3, AC011389.1, AC105290.1, AC025159.1, AC005237.1, AC008691.1, AP001341.1, CCN1, AC104170.1, AC008014.1, AC012355.1, AC034231.1, AC073487.1, AL592043.1, AC011444.3, AL078602.1, AL355835.1, AC091946.1, AC087762.1, FAM198B-AS1, AC079142.1, AL158198.1, HCG20, AL356277.3, TAFA2, AC005358.1, Z98742.4, AL158167.1, AC027045.2, LINC01748, AL109984.1, AC004160.1, AC012404.1, RBMS3-AS2, AC073529.1, AC090578.1, AC011029.1, AC104088.1, AL031602.2, LINC02156, AF165147.1, AC098829.1, RSPH10B2, AC025259.1, AC244502.1, AC106729.1, LINC02006, AP003086.1, AC007448.5, AC099788.1, AL354949.1, AC022001.2, AC025614.2, AC078802.1, AC027627.1, AC025774.1, AC008574.1, AC007009.1, AC073130.1, AC083880.1, AC009812.4, AC079209.1, AL162394.1, LINC02712, AC023794.1, LINC00596, AL583810.1, AC007221.1, LINC01895, AP001029.1, AC005808.1, AC023781.1, AC104777.1, AC090099.1, AC034238.1, AL354824.1, AC034268.2, AC092353.2, AL355490.2, LINC02698, AL109946.1, NIBAN3, AC040168.1, AC120193.1, LINC02257, AC137932.2, AL450352.1, AP002383.2, AC022034.3, AL365318.1, AL138899.1, AC096645.1, BX323046.2, AC013275.1, AC116096.1, AC109811.1, AC010245.1, AL162719.1, AL359632.1, AC079296.1, AP003501.1, AP001993.1, MAPK6-DT, AC092376.1, AL121672.3, LINC02318, AC108075.1, BX640514.2, LINC01853, AC124290.2, AL122014.1, LINC02713, AC099511.1, AL596223.1, AC003043.2, AC244131.2, AC004053.1, LINC02446, AL359644.1, AL049828.1, AL355490.1, AC009097.1, AC027237.2, GOLGA6L7, AC018618.1, CCN2, AP001011.1, AC097376.3, AC002069.2, AC012464.1, AC008149.2, AL589990.1, AL359232.1, AL353660.1, AP004608.1, AL137009.1, AC097522.2, AC005224.2, AC011287.1, LINC02320, SCAT2, AC119396.1, AL590006.1, AC078881.1, AC015849.1, AP001021.3, AC078845.1, AC078785.1, AC117453.1, AC026167.1, AC107881.1, AC007614.1, IGHG1, AC026316.5, AL365255.1, LINC02391, AC104078.2, AL109935.1, AL136115.3, LINC01709, AL359764.3, AC006369.2, AC017002.6, AC010280.1, AC090192.2, AC044839.3, AC099518.4, AC006942.1, AP001599.1, SMIM36, AL139246.3, AL031293.1, AL513218.2, AC023481.1, AC072022.1, AC093240.1, AL451080.1, AP001363.2, PLAAT5, RSF1-IT2, AP000820.2, LINC02327, AL161804.1, AL132712.2, AC100839.2, AC020779.2, AC124248.2, AC026471.5, AC092364.1, AC005394.1, AL732314.4, LINC02836, AL137224.1, AC119674.1, NIBAN1, AC073840.1, AC016074.2, RESF1, AC061958.1, AC022182.1, AC015631.1, AC026347.1, UFL1-AS1, AC0082 ...
# PC_ 1
# Positive:  FN1, COL6A3, COL3A1, GPC6, COL1A2, PLXDC2, BICC1, COL5A2, RBMS3, PTPRG
# 	   VCAN, SERPINE1, EBF1, APBB2, LAMB1, FBN1, GLIS3, BNC2, COL1A1, CALD1
# 	   COL4A2, COL4A1, FRMD4A, ZFHX3, EXT1, ZBTB16, KAZN, SASH1, SAT1, TSHZ2
# Negative:  ARHGAP15, FGF12, RYR2, PARP8, SKAP1, PRKCH, RIPOR2, TTN, CD247, THEMIS
# 	   MLIP, SAMD3, AOAH, ITGA4, TC2N, INPP4B, CD96, PIP4K2A, MYL2, TOX
# 	   PYHIN1, MYH7, LINC01934, TNFAIP8, CAMK4, BCL2, ANK3, CDC14A, SYTL3, RASGRP1
# PC_ 2
# Positive:  FKBP5, PARP8, PIP4K2A, MAML2, CD96, ZBTB16, SYTL3, PDE3B, RORA, PRKCH
# 	   ARHGAP15, AOAH, THEMIS, PLXDC2, TC2N, LDLRAD4, CNOT6L, SKAP1, IL7R, CEMIP2
# 	   RBMS3, LAMA2, SCML4, TACC1, PTPRG, HERC1, INPP4B, CRYBG1, SLC4A7, TNFAIP8
# Negative:  TTN, MYH6, TIMP1, FN1, RBFOX1, RAP1GAP2, RYR2, MYL2, CFD, TCAP
# 	   FGF12, PDE1C, APOD, THBS1, TNC, NCAM1, LINC01505, MEIS1, DLGAP1, NRXN3
# 	   SPP1, KIF26B, CMYA5, EGF, KIFC3, CNTN5, MYOM2, PLA2G2A, CHRM2, PRICKLE1
# PC_ 3
# Positive:  RYR2, FGF12, MLIP, TTN, LAMA2, MCTP2, AOAH, NCAM1, PRKG1, PDE1C
# 	   CD247, KLRD1, CMYA5, TXK, DST, CD36, PLCB1, DLG2, LHFPL6, PDGFD
# 	   TNNI3K, GNLY, PCDH7, DLC1, NCALD, VAV3, MYH7, KLRF1, RBMS3, MIR99AHG
# Negative:  IL7R, THEMIS, CAMK4, FKBP5, SERINC5, PDE3B, CDC14A, TC2N, INPP4B, KCNMA1
# 	   CRYBG1, LDLRAD4, SERPINE1, TNFAIP8, PCAT1, RASA3, LEF1, GPC6, RAD51B, ARHGAP15
# 	   CD96, LINC01934, RASGRF2, MAML2, RUNX2, NELL2, COL3A1, SLC16A10, ARHGEF18, IFNG-AS1
# PC_ 4
# Positive:  AOAH, SYTL3, MCTP2, KLRD1, VAV3, CD247, PIP4K2A, PYHIN1, TXK, CEMIP2
# 	   TOX, KCNMA1, KLRF1, PRKCH, HIPK2, DTHD1, APBA2, CMIP, SAMD3, ZBTB16
# 	   GNLY, LYST, NCR1, ATP8B4, GSAP, HIP1, KLRK1, SYK, PTGDR, SERPINE1
# Negative:  RYR2, INPP4B, IL7R, ANK3, TTN, FGF12, THEMIS, BCL2, SERINC5, LAMA2
# 	   CAMK4, MLIP, ARHGAP15, ADAM19, CMYA5, CDC14A, PRKCA, PDE1C, DST, BACH2
# 	   DLC1, LHFPL6, DCN, MDFIC, TC2N, RIPOR2, TNNI3K, MIR99AHG, CD36, DLG2
# PC_ 5
# Positive:  THEMIS, AOAH, TOX, LINC01934, TC2N, DCN, DTHD1, SAMD3, LYST, FN1
# 	   FBN1, GSN, TIMP1, PPP2R2B, SKAP1, PYHIN1, SPARCL1, CCL5, CEMIP2, MSC-AS1
# 	   CDH19, PARP8, CFD, SLIT2, ABCA8, VCAN, SLAMF6, PIP4K2A, SLC4A7, TNXB
# Negative:  TXK, IL7R, FKBP5, ZBTB16, PRKCA, SERINC5, RIPOR2, HIPK2, NCAM1, RUNX2
# 	   ANK3, LDLRAD4, LEF1, CD247, KCNMA1, BACH2, FGF12, PTPRG, RASA3, BCL2
# 	   MLIP, ATP10A, TBXAS1, CDC14A, TARSL2, LINC00299, ARHGEF18, XIST, PRKG1, GNLY

# %%
if(!dir.exists("../data/coembed")){
    dir.create("../data/coembed")
}

# %%
saveRDS(obj.rna, file = "../data/snRNA/snRNA.Rds")
saveRDS(obj.atac, file = "../data/snATAC/snATAC.Rds")
saveRDS(coembed, file = "../data/coembed/coembed.Rds")

# %%
sessionInfo()
# Out:
# R version 4.0.3 (2020-10-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: CentOS Linux 8
#
# Matrix products: default
# BLAS/LAPACK: /home/rs619065/miniconda3/envs/r-4.0.3/lib/libopenblasp-r0.3.12.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] cowplot_1.1.1               dplyr_1.0.7
#  [3] harmony_1.0                 Rcpp_1.0.7
#  [5] Signac_1.4.0                SeuratObject_4.0.2
#  [7] Seurat_4.0.5                ArchR_1.0.1
#  [9] magrittr_2.0.1              rhdf5_2.34.0
# [11] Matrix_1.3-4                data.table_1.14.2
# [13] SummarizedExperiment_1.20.0 Biobase_2.50.0
# [15] GenomicRanges_1.42.0        GenomeInfoDb_1.26.7
# [17] IRanges_2.24.1              S4Vectors_0.28.1
# [19] BiocGenerics_0.36.1         MatrixGenerics_1.2.1
# [21] matrixStats_0.61.0          ggplot2_3.3.5
#
# loaded via a namespace (and not attached):
#   [1] uuid_1.0-3             fastmatch_1.1-3        plyr_1.8.6
#   [4] igraph_1.2.8           repr_1.1.3             lazyeval_0.2.2
#   [7] splines_4.0.3          BiocParallel_1.24.1    listenv_0.8.0
#  [10] scattermore_0.7        SnowballC_0.7.0        digest_0.6.28
#  [13] htmltools_0.5.2        fansi_0.5.0            tensor_1.5
#  [16] cluster_2.1.2          ROCR_1.0-11            globals_0.14.0
#  [19] Biostrings_2.58.0      docopt_0.7.1           spatstat.sparse_2.0-0
#  [22] colorspace_2.0-2       ggrepel_0.9.1          sparsesvd_0.2
#  [25] crayon_1.4.2           RCurl_1.98-1.5         jsonlite_1.7.2
#  [28] spatstat.data_2.1-0    survival_3.2-13        zoo_1.8-9
#  [31] glue_1.5.0             polyclip_1.10-0        gtable_0.3.0
#  [34] zlibbioc_1.36.0        XVector_0.30.0         leiden_0.3.9
#  [37] DelayedArray_0.16.3    Rhdf5lib_1.12.1        future.apply_1.8.1
#  [40] abind_1.4-5            scales_1.1.1           DBI_1.1.1
#  [43] miniUI_0.1.1.1         viridisLite_0.4.0      xtable_1.8-4
#  [46] reticulate_1.22        spatstat.core_2.3-1    htmlwidgets_1.5.4
#  [49] httr_1.4.2             RColorBrewer_1.1-2     ellipsis_0.3.2
#  [52] ica_1.0-2              pkgconfig_2.0.3        farver_2.1.0
#  [55] ggseqlogo_0.1          uwot_0.1.10            deldir_1.0-6
#  [58] utf8_1.2.2             labeling_0.4.2         tidyselect_1.1.1
#  [61] rlang_0.4.12           reshape2_1.4.4         later_1.3.0
#  [64] munsell_0.5.0          tools_4.0.3            generics_0.1.1
#  [67] ggridges_0.5.3         evaluate_0.14          stringr_1.4.0
#  [70] fastmap_1.1.0          goftest_1.2-3          fitdistrplus_1.1-6
#  [73] purrr_0.3.4            RANN_2.6.1             pbapply_1.5-0
#  [76] future_1.23.0          nlme_3.1-153           mime_0.12
#  [79] slam_0.1-48            RcppRoll_0.3.0         compiler_4.0.3
#  [82] plotly_4.10.0          png_0.1-7              spatstat.utils_2.2-0
#  [85] tibble_3.1.6           tweenr_1.0.2           stringi_1.7.5
#  [88] RSpectra_0.16-0        lattice_0.20-45        IRdisplay_1.0
#  [91] vctrs_0.3.8            pillar_1.6.4           lifecycle_1.0.1
#  [94] rhdf5filters_1.2.1     spatstat.geom_2.3-0    lmtest_0.9-39
#  [97] RcppAnnoy_0.0.19       bitops_1.0-7           irlba_2.3.3
# [100] httpuv_1.6.3           patchwork_1.1.1        R6_2.5.1
# [103] promises_1.2.0.1       KernSmooth_2.23-20     gridExtra_2.3
# [106] lsa_0.73.2             parallelly_1.28.1      codetools_0.2-18
# [109] gtools_3.9.2           MASS_7.3-54            assertthat_0.2.1
# [112] withr_2.4.2            qlcMatrix_0.9.7        sctransform_0.3.2
# [115] Rsamtools_2.6.0        GenomeInfoDbData_1.2.4 mgcv_1.8-38
# [118] grid_4.0.3             rpart_4.1-15           IRkernel_1.2
# [121] tidyr_1.1.4            Cairo_1.5-12.2         Rtsne_0.15
# [124] pbdZMQ_0.3-6           ggforce_0.3.3          shiny_1.7.1
# [127] base64enc_0.1-3
