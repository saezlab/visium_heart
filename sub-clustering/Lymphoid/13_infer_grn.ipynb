# %%
suppressMessages(library(ArchR))
suppressMessages(library(Seurat))
suppressMessages(library(Signac))
suppressMessages(library(dplyr))
suppressMessages(library(cowplot))
suppressMessages(library(Nebulosa))
suppressMessages(library(ggpubr))
suppressMessages(library(BSgenome.Hsapiens.UCSC.hg38))
suppressMessages(library(EnsDb.Hsapiens.v86))
suppressMessages(library(Pando))

# %%
set.seed(42)
getwd()
# Out:
# [1] "/data/scATA/SingleCellOpenChromatin/local/VisiumHeartRevision/IntegrativeAnalysis/Lymphoid/code"

# %%
coembed <- readRDS("../data/coembed/coembed.annotation.Rds")
coembed
# Out:
# An object of class Seurat
# 159644 features across 3473 samples within 3 assays
# Active assay: RNA (28933 features, 2000 variable features)
#  2 other assays present: peaks, GeneActivity
#  5 dimensional reductions calculated: pca, umap, harmony, umap_harmony, umap_harmony_v2

# %%
obj.atac <- subset(coembed, tech == "ATAC")
obj.rna <- subset(coembed, tech == "RNA")

obj.atac
obj.rna
# Out:
# An object of class Seurat
# 159644 features across 858 samples within 3 assays
# Active assay: RNA (28933 features, 2000 variable features)
#  2 other assays present: peaks, GeneActivity
#  5 dimensional reductions calculated: pca, umap, harmony, umap_harmony, umap_harmony_v2
# An object of class Seurat
# 159644 features across 2615 samples within 3 assays
# Active assay: RNA (28933 features, 2000 variable features)
#  2 other assays present: peaks, GeneActivity
#  5 dimensional reductions calculated: pca, umap, harmony, umap_harmony, umap_harmony_v2

# %%
df_cell_pairing <- readRDS("../data/coembed/ATAC_RNA_matching.rds")
df_cell_pairing$cell_name <- paste0("cell-", 1:nrow(df_cell_pairing))

head(df_cell_pairing)
# Out:
#   ATAC                     RNA                          cell_name
# 1 CK171#TCACCACAGCCATCAT-1 CAACCTCTCGGTTCAA-1_1_1_1     cell-1
# 2 CK171#GAGACTTGTAAGCCGA-1 TCACGCTAGCGATGCA-1_1_1_1_1   cell-2
# 3 CK171#GACCCAGCATTTAGGC-1 CGTTCTGTCACTCGAA-1_2_1_1_1_1 cell-3
# 4 CK171#AAGGTTCGTCGCTACG-1 AGGACTTTCCCATAGA-1_1_1_1_1   cell-4
# 5 CK171#AATGGCTGTTACGAAA-1 GGTTAACTCGCTCTAC-1_2_1       cell-5
# 6 CK171#AAAGATGAGCCTGTAT-1 TGTCCTGTCTCCGAGG-1_2_1_1_1_1 cell-6

# %%
atac_counts <- obj.atac@assays$peaks@counts[, df_cell_pairing$ATAC]
rna_counts <- obj.rna@assays$RNA@counts[, df_cell_pairing$RNA]

## unify the cell names in ATAC and RNA
colnames(atac_counts) <- df_cell_pairing$cell_name
colnames(rna_counts) <- df_cell_pairing$cell_name

## create seurat object for Pando
obj <- CreateSeuratObject(counts = rna_counts, assay = "RNA")

obj[['peaks']] <- CreateChromatinAssay(counts = atac_counts,
                                      genome = "hg38")

DefaultAssay(obj) <- "peaks"

obj
# Out:
# An object of class Seurat
# 140618 features across 858 samples within 2 assays
# Active assay: peaks (111685 features, 0 variable features)
#  1 other assay present: RNA

# %%
## add annotation for each peak
# extract gene annotations from EnsDb
annotations <- GetGRangesFromEnsDb(ensdb = EnsDb.Hsapiens.v86, verbose = FALSE)
seqlevelsStyle(annotations) <- 'UCSC'
genome(annotations) <- "hg38"

# add the gene information to the object
Annotation(obj[["peaks"]]) <- annotations
# Out:
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"

# %%
# Select variable features
DefaultAssay(obj) <- "RNA"

obj <- obj %>%
    NormalizeData() %>%
    FindVariableFeatures()

# %%
# Initiate GRN object and select candidate regions
obj <- initiate_grn(obj, exclude_exons = FALSE)

# %%
## get motifs
suppressMessages(library(JASPAR2020))
suppressMessages(library(TFBSTools))

opts <- list()
opts["species"] <- "Homo sapiens"
opts["collection"] <- "CORE"
motifs <- getMatrixSet(JASPAR2020, opts)

motif_tfs <- as.data.frame(name(motifs))
motif_tfs$motif <- rownames(motif_tfs)
colnames(motif_tfs)  <- c("tf", "motif")

motif_tfs <- motif_tfs[, c("motif", "tf")]

head(motif_tfs)

nrow(motif_tfs)
# Out:
#          motif    tf
# MA0030.1 MA0030.1 FOXF2
# MA0031.1 MA0031.1 FOXD1
# MA0051.1 MA0051.1 IRF2
# MA0057.1 MA0057.1 MZF1(var.2)
# MA0059.1 MA0059.1 MAX::MYC
# MA0066.1 MA0066.1 PPARG
# [1] 633

# %%
# Scan candidate regions for TF binding motifs
obj <- find_motifs(
    obj,
    pfm = motifs,
    motif_tfs = motif_tfs,
    genome = BSgenome.Hsapiens.UCSC.hg38
)
# Out:
# Adding TF info
#
# Building motif matrix
#
# Finding motif positions
#
# Creating Motif object

# %%
# Infer gene regulatory network
obj <- infer_grn(obj,
                peak_to_gene_method = 'Signac',
                 method = 'glm')
# Out:
# Selecting candidate regulatory regions near genes
#
# Preparing model input
#
# Fitting models for 1462 target genes

# %%
df <- as.data.frame(obj@grn@networks$glm_network@coefs) %>%
    subset(padj < 0.05)

head(df)
# Out:
#    tf    target   region                   term
# 16 MEIS3 BCOR     chrX-40098312-40098812   chrX_40098312_40098812:MEIS3
# 34 USF1  MTMR8    chrX-64395225-64395725   chrX_64395225_64395725:USF1
# 41 BATF  MSN      chrX-65723649-65724149   BATF:chrX_65723649_65724149
# 59 SPI1  PAK3     chrX-111098751-111099251 chrX_111098751_111099251:SPI1
# 60 MGA   PAK3     chrX-111098751-111099251 chrX_111098751_111099251:MGA
# 66 KLF11 CXorf40A chrX-149540298-149540798 chrX_149540298_149540798:KLF11
#    estimate  std_err    statistic pval         padj
# 16 0.6205188 0.09470899  6.551847 9.801397e-11 1.108234e-09
# 34 0.4564577 0.12448931  3.666642 2.609154e-04 1.640040e-03
# 41 0.5986432 0.22571948  2.652156 8.147016e-03 4.055076e-02
# 59 0.3251020 0.06202882  5.241145 2.011751e-07 1.752317e-06
# 60 0.1698445 0.03296069  5.152942 3.185931e-07 2.731812e-06
# 66 0.5064376 0.04789442 10.574042 1.209418e-24 2.638108e-23

# %%
length(unique(obj@grn@networks$glm_network@coefs$target))
# Out:
# [1] 1007

# %%
obj <- find_modules(obj)

# %%
modules <- NetworkModules(obj)
#modules@meta
#modules@features

# %%
modules@meta
# Out:
#     target    tf      estimate      n_regions n_genes n_tfs
# 1   HMBS      CREB3   0.502456918   1         1       1
# 2   TNNT3     E2F6    0.150808737   2         1       2
# 3   BBC3      EGR2    0.221948001   3         1       3
# 4   KEAP1     EGR3    1.008195189   3         1       2
# 5   GZMB      EHF     0.644146878   4         1       3
# 6   TOP1MT    ELF3    0.415747555   3         1       3
# 7   LINC01569 ELK3    0.013216023   3         2       2
# 8   SPSB2     ELK3    0.003256462   3         2       2
# 9   FCN3      ELK4    0.061526038   2         3       2
# 10  SNHG15    ELK4    0.256699658   4         3       3
# 11  STAP2     ELK4    0.035338163   2         3       2
# 12  STOML2    ESR1    0.182048769   3         1       2
# 13  CCR7      ESR2    0.429512770   4         3       3
# 14  FCGR3A    ESR2    0.341330263   5         3       5
# 15  NLGN2     ESR2    0.110788987   3         3       1
# 16  SYTL3     ETS1    0.183452614   1         1       1
# 17  PTCSC2    ETS2    0.498485796   1         1       1
# 18  DAXX      ETV4    0.491687344   8         1       3
# 19  AFMID     ETV5    0.212461085   3         1       3
# 20  CCR7      ETV6    0.130363935   4         1       3
# 21  SERINC5   FOXP1   0.314644062   3         1       2
# 22  CTU2      FOXP2   0.064735297   8         1       2
# 23  ATP6V1G2  GABPA   0.188905241   5         1       4
# 24  BBC3      GFI1    0.492520606   3         2       3
# 25  FBXO2     GFI1    0.358505134   1         2       1
# 26  AFMID     GLI2    0.404393915   3         1       3
# 27  ZNF843    GLIS2   0.321331869   4         1       4
# 28  BBC3      HIC2    0.666970140   3         1       3
# 29  CREB3L4   HOXB2   0.498664799   3         1       2
# 30  FCGR3A    HOXB4   0.828054849   5         1       5
# ⋮   ⋮         ⋮       ⋮             ⋮         ⋮       ⋮
# 119 MORN3     ZBTB14   0.8318287039 4         1       3
# 120 DALRD3    ZBTB18   1.0167926147 2         2       2
# 121 FCN3      ZBTB18   0.6407947401 2         2       2
# 122 GSTO2     ZBTB33   0.4757434981 1         1       1
# 123 DALRD3    ZBTB6    0.9895490015 2         2       2
# 124 VAMP5     ZBTB6    0.4881793017 2         2       2
# 125 DAXX      ZKSCAN5  0.9722396972 8         2       3
# 126 KLF16     ZKSCAN5  0.5000000000 4         2       2
# 127 C16orf74  ZNF135   0.3696168578 2         2       2
# 128 TNNT3     ZNF135   0.9969535196 2         2       2
# 129 TOP1MT    ZNF143   0.5171160910 3         1       3
# 130 CLIC3     ZNF148   0.7189429748 7         1       2
# 131 FDXR      ZNF16    0.7657769925 2         2       2
# 132 IRGQ      ZNF16    1.2608986329 3         2       3
# 133 C2CD2L    ZNF263   0.8435557001 5         3       3
# 134 MORN3     ZNF263   0.1730188735 4         3       3
# 135 TOP1MT    ZNF263   0.0339685661 3         3       3
# 136 MORN3     ZNF274   0.4962315004 4         1       3
# 137 SLC15A3   ZNF282   1.4494766817 4         1       2
# 138 TM9SF1    ZNF341   0.2128660511 5         1       3
# 139 VWA1      ZNF382   1.3110463427 3         1       2
# 140 NAXE      ZNF384   0.1316343652 1         1       2
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] TFBSTools_1.32.0                  JASPAR2020_0.99.10
#  [3] Pando_0.4.2                       EnsDb.Hsapiens.v86_2.99.0
#  [5] ensembldb_2.18.2                  AnnotationFilter_1.18.0
#  [7] GenomicFeatures_1.46.1            AnnotationDbi_1.56.2
#  [9] BSgenome.Hsapiens.UCSC.hg38_1.4.4 BSgenome_1.62.0
# [11] rtracklayer_1.54.0                Biostrings_2.62.0
# [13] XVector_0.34.0                    ggpubr_0.4.0
# [15] Nebulosa_1.4.0                    patchwork_1.1.1
# [17] cowplot_1.1.1                     dplyr_1.0.7
# [19] Signac_1.4.0                      SeuratObject_4.0.4
# [21] Seurat_4.0.5                      ArchR_1.0.1
# [23] magrittr_2.0.1                    rhdf5_2.38.0
# [25] Matrix_1.3-4                      data.table_1.14.2
# [27] SummarizedExperiment_1.24.0       Biobase_2.54.0
# [29] GenomicRanges_1.46.1              GenomeInfoDb_1.30.0
# [31] IRanges_2.28.0                    S4Vectors_0.32.3
# [33] BiocGenerics_0.40.0               MatrixGenerics_1.6.0
# [35] matrixStats_0.61.0                ggplot2_3.3.5
#
# loaded via a namespace (and not attached):
#   [1] rappdirs_0.3.3              SnowballC_0.7.0
#   [3] pbdZMQ_0.3-6                scattermore_0.7
#   [5] R.methodsS3_1.8.1           tidyr_1.1.4
#   [7] bit64_4.0.5                 knitr_1.36
#   [9] R.utils_2.11.0              irlba_2.3.3
#  [11] DelayedArray_0.20.0         rpart_4.1-15
#  [13] KEGGREST_1.34.0             RCurl_1.98-1.5
#  [15] generics_0.1.1              RSQLite_2.2.8
#  [17] RANN_2.6.1                  future_1.23.0
#  [19] tzdb_0.2.0                  bit_4.0.4
#  [21] spatstat.data_2.1-0         xml2_1.3.2
#  [23] httpuv_1.6.3                assertthat_0.2.1
#  [25] DirichletMultinomial_1.36.0 xfun_0.28
#  [27] hms_1.1.1                   evaluate_0.14
#  [29] promises_1.2.0.1            fansi_0.5.0
#  [31] restfulr_0.0.13             progress_1.2.2
#  [33] caTools_1.18.2              dbplyr_2.1.1
#  [35] igraph_1.2.9                DBI_1.1.1
#  [37] htmlwidgets_1.5.4           sparsesvd_0.2
#  [39] spatstat.geom_2.3-0         purrr_0.3.4
#  [41] ellipsis_0.3.2              ks_1.13.2
#  [43] backports_1.4.0             annotate_1.72.0
#  [45] biomaRt_2.50.1              deldir_1.0-6
#  [47] sparseMatrixStats_1.6.0     vctrs_0.3.8
#  [49] SingleCellExperiment_1.16.0 ROCR_1.0-11
#  [51] abind_1.4-5                 cachem_1.0.6
#  [53] withr_2.4.2                 grr_0.9.5
#  [55] ggforce_0.3.3               checkmate_2.0.0
#  [57] sctransform_0.3.2           GenomicAlignments_1.30.0
#  [59] prettyunits_1.1.1           mclust_5.4.8
#  [61] goftest_1.2-3               cluster_2.1.2
#  [63] IRdisplay_1.0               lazyeval_0.2.2
#  [65] seqLogo_1.60.0              crayon_1.4.2
#  [67] pkgconfig_2.0.3             slam_0.1-49
#  [69] tweenr_1.0.2                nlme_3.1-153
#  [71] ProtGenerics_1.26.0         nnet_7.3-16
#  [73] rlang_0.4.12                globals_0.14.0
#  [75] lifecycle_1.0.1             miniUI_0.1.1.1
#  [77] filelock_1.0.2              BiocFileCache_2.2.0
#  [79] dichromat_2.0-0             polyclip_1.10-0
#  [81] lmtest_0.9-39               ggseqlogo_0.1
#  [83] IRkernel_1.2.0.9000         carData_3.0-4
#  [85] Matrix.utils_0.9.8          Rhdf5lib_1.16.0
#  [87] zoo_1.8-9                   base64enc_0.1-3
#  [89] ggridges_0.5.3              png_0.1-7
#  [91] viridisLite_0.4.0           rjson_0.2.20
#  [93] bitops_1.0-7                R.oo_1.24.0
#  [95] KernSmooth_2.23-20          rhdf5filters_1.6.0
#  [97] blob_1.2.2                  stringr_1.4.0
#  [99] parallelly_1.29.0           readr_2.1.0
# [101] jpeg_0.1-9                  rstatix_0.7.0
# [103] ggsignif_0.6.3              CNEr_1.30.0
# [105] scales_1.1.1                memoise_2.0.0
# [107] plyr_1.8.6                  ica_1.0-2
# [109] zlibbioc_1.40.0             compiler_4.1.1
# [111] BiocIO_1.4.0                RColorBrewer_1.1-2
# [113] fitdistrplus_1.1-6          Rsamtools_2.10.0
# [115] listenv_0.8.0               pbapply_1.5-0
# [117] htmlTable_2.3.0             Formula_1.2-4
# [119] MASS_7.3-54                 mgcv_1.8-38
# [121] tidyselect_1.1.1            stringi_1.7.5
# [123] yaml_2.2.1                  latticeExtra_0.6-29
# [125] ggrepel_0.9.1               grid_4.1.1
# [127] VariantAnnotation_1.40.0    fastmatch_1.1-3
# [129] tools_4.1.1                 future.apply_1.8.1
# [131] parallel_4.1.1              rstudioapi_0.13
# [133] uuid_1.0-3                  TFMPvalue_0.0.8
# [135] foreign_0.8-81              lsa_0.73.2
# [137] gridExtra_2.3               farver_2.1.0
# [139] Rtsne_0.15                  digest_0.6.28
# [141] shiny_1.7.1                 pracma_2.3.3
# [143] qlcMatrix_0.9.7             motifmatchr_1.16.0
# [145] Rcpp_1.0.7                  car_3.0-12
# [147] broom_0.7.10                later_1.3.0
# [149] RcppAnnoy_0.0.19            httr_1.4.2
# [151] biovizBase_1.42.0           colorspace_2.0-2
# [153] XML_3.99-0.8                tensor_1.5
# [155] reticulate_1.22             splines_4.1.1
# [157] uwot_0.1.10                 RcppRoll_0.3.0
# [159] spatstat.utils_2.2-0        plotly_4.10.0
# [161] xtable_1.8-4                poweRlaw_0.70.6
# [163] jsonlite_1.7.2              R6_2.5.1
# [165] Hmisc_4.6-0                 pillar_1.6.4
# [167] htmltools_0.5.2             mime_0.12
# [169] glue_1.5.0                  fastmap_1.1.0
# [171] BiocParallel_1.28.1         codetools_0.2-18
# [173] mvtnorm_1.1-3               utf8_1.2.2
# [175] lattice_0.20-45             spatstat.sparse_2.0-0
# [177] tibble_3.1.6                curl_4.3.2
# [179] leiden_0.3.9                gtools_3.9.2
# [181] GO.db_3.14.0                survival_3.2-13
# [183] repr_1.1.3                  docopt_0.7.1
# [185] munsell_0.5.0               GenomeInfoDbData_1.2.7
# [187] reshape2_1.4.4              gtable_0.3.0
# [189] spatstat.core_2.3-1
